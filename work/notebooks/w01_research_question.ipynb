# %% [markdown]
# <a href="https://colab.research.google.com/github/7syedmudassarali/Flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#AI-powered education and student performance tools. I chose this lane because I am already building a quiz portal for university courses and want to explore how data and AI can help instructors understand student performance and improve assessments. It is practical, connected to a real problem I have access to, and gives me a clear way to test whether the work is actually useful.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# The main decision is which students, questions, or topics need attention. Instructors would use the results to identify weak areas, adjust quizzes, and decide where students need more support. A wrong recommendation could waste an instructor's time, give students unnecessary support, or cause a genuinely weak topic or student group to be missed.
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# I would use the starter CSV to report 2–3 actual numbers such as the number of students, number of quiz attempts, and average score. These numbers will show whether there is enough real activity and variation in the data to make the next 7 weeks worthwhile.
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# I can claim that the work provides observed patterns and directional insights from quiz and student-performance data, and that it can support instructors in making decisions about assessments and student support. I can evaluate whether the recommendations are useful against the available data. I cannot claim causal proof, that the AI caused an improvement in performance, or that the system can reliably predict future student outcomes without proper validation. I also cannot claim to “predict Google” or make conclusions beyond what the available data supports.
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
